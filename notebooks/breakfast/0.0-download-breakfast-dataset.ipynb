# %%
# %load_ext autoreload
# %autoreload 2

# %%
from childes_mi.utils.paths import DATA_DIR, ensure_dir, BREAKFAST_DIR
import urllib.request

# %%
annotations_address = "https://uni-bonn.sciebo.de/s/I5hJN7ka53PqlC0/download"

# %%
save_loc = BREAKFAST_DIR / "segmentation_fine.tar.gz"

# %%
# make sure there is a directory to save to
ensure_dir(save_loc)

# %%
# save to disk
urllib.request.urlretrieve(annotations_address, save_loc)
# Out:
# (PosixPath('/mnt/cube/tsainbur/Projects/github_repos/childes_mi_project/data/raw/BREAKFAST_Data_Dir/segmentation_fine.tar.gz'),
#  <http.client.HTTPMessage at 0x7f98acb40208>)

# %%
slp = save_loc.as_posix()
bd = BREAKFAST_DIR.as_posix()
slp, bd
# Out:
# ('/mnt/cube/tsainbur/Projects/github_repos/childes_mi_project/data/raw/BREAKFAST_Data_Dir/segmentation_fine.tar.gz',
#  '/mnt/cube/tsainbur/Projects/github_repos/childes_mi_project/data/raw/BREAKFAST_Data_Dir')

# %%
# !tar -xvf $slp --directory $bd
# Out:
# segmentation_fine/salat/P05_webcam01_P05_salat.xml
# segmentation_fine/coffee/P24_cam02_P24_coffee.txt
# segmentation_fine/sandwich/P22_cam01_P22_sandwich.txt
# segmentation_fine/pancake/P18_cam01_P18_pancake.xml
# segmentation_fine/juice/P05_cam02_P05_juice.xml
# segmentation_fine/sandwich/P07_cam01_P07_sandwich.xml
# segmentation_fine/scrambledegg/P48_webcam01_P48_scrambledegg.txt
# segmentation_fine/tea/P26_webcam01_P26_tea.txt
# segmentation_fine/juice/P06_webcam02_P06_juice.txt
# segmentation_fine/tea/P08_stereo01_P08_tea.xml
# segmentation_fine/coffee/P14_stereo01_P14_coffee.txt
# segmentation_fine/tea/P05_webcam01_P05_tea.xml
# segmentation_fine/milk/P54_webcam01_P54_milk.xml
# segmentation_fine/scrambledegg/P12_cam01_P12_scrambledegg.txt
# segmentation_fine/coffee/P24_stereo01_P24_coffee.xml
# segmentation_fine/friedegg/P07_webcam01_P07_friedegg.txt
# segmentation_fine/coffee/P05_webcam01_P05_coffee.txt
# segmentation_fine/salat/P19_stereo01_P19_salat.xml
# ...
